# %% [markdown]
# ## Weights and Biases Log Setup

# %%
# %load_ext autoreload
# %autoreload 2

import random
import wandb

import deep_learning_land_use_classification.config as config

# Start a new wandb run to track this script.
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="sstaheli52-wageningen-university-and-research",
    
    # Set the wandb project where this run will be logged.
    project="our-awesome-project",
    dir = config.WANDB_DIR,

    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.02,
        "architecture": "CNN",
        "dataset": "CIFAR-100",
        "epochs": 10,
    },
)

# Simulate training.
epochs = 10
offset = random.random() / 5
for epoch in range(2, epochs):
    acc = 1 - 2**-epoch - random.random() / epoch - offset
    loss = 2**-epoch + random.random() / epoch + offset

    # Log metrics to wandb.
    run.log({"acc": acc, "loss": loss})

# Finish the run and upload any remaining data.
run.finish()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Tracking run with wandb version 0.26.0
# Run data is saved locally in <code>/Users/user/Dropbox/My_Mac/Documents/Wageningen/Coursework/Period_5/Deep_learning/DL_landuse_classification_project/Deep-learning-land-use-classification/wandb/wandb/run-20260414_103525-e0jx4vlx</code>
# Syncing run <strong><a href='https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project/runs/e0jx4vlx' target="_blank">ethereal-wave-5</a></strong> to <a href='https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project' target="_blank">https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project</a>
#  View run at <a href='https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project/runs/e0jx4vlx' target="_blank">https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project/runs/e0jx4vlx</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▅▄▆▇▇▇█</td></tr><tr><td>loss</td><td>█▄▂▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.81108</td></tr><tr><td>loss</td><td>0.20396</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-wave-5</strong> at: <a href='https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project/runs/e0jx4vlx' target="_blank">https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project/runs/e0jx4vlx</a><br> View project at: <a href='https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project' target="_blank">https://wandb.ai/sstaheli52-wageningen-university-and-research/our-awesome-project</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/Users/user/Dropbox/My_Mac/Documents/Wageningen/Coursework/Period_5/Deep_learning/DL_landuse_classification_project/Deep-learning-land-use-classification/wandb/wandb/run-20260414_103525-e0jx4vlx/logs</code>
